# %% [markdown]
# # DA6401 Assignment 1 - Report Plots and Analysis
#
# This notebook contains helper code for analyzing W&B sweep results and generating any additional plots required for the report.

# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ## 1. Load Sweep Data (Optional)
# You can use the W&B API to load your 100 sweep runs for custom plotting if needed.

# %%
# api = wandb.Api()
# sweep = api.sweep("YOUR_ENTITY/da6401_assignment_1/SWEEP_ID")
# runs_df = pd.DataFrame([{
#     'id': run.id,
#     'val_accuracy': run.summary.get('val_accuracy'),
#     'optimizer': run.config.get('optimizer'),
#     'learning_rate': run.config.get('learning_rate'),
#     'activation': run.config.get('activation')
# } for run in sweep.runs])

# %% [markdown]
# ## 2. Custom Visualizations
# Example: Scatter plot of Train vs Val Accuracy (Q2.7)

# %%
# plt.figure(figsize=(8, 6))
# sns.scatterplot(data=runs_df, x='train_accuracy', y='val_accuracy')
# plt.title("Global Performance Analysis: Train vs Val Accuracy")
# plt.show()
